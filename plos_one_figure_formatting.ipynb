# %%
import sys
import os

from utils.visuals import export_plos_tiff, inspect_image, show_tiff

# %%
output = 'figures/final_figures/fig1.tiff'

export_plos_tiff('figures/annotated_figures/fig1_aramai_point_rocks.jpg', output_path= 'figures/final_figures/fig1.tiff')
inspect_image('figures/final_figures/fig1.tiff')
show_tiff('figures/final_figures/fig1.tiff')
# Out:
# Original size: 2853 x 2015 px
# Resized to: 2250 x 1589 px
# Saved PLOS-compliant TIFF to: figures/final_figures/fig1.tiff
# Mode: RGB
# Size: (2250, 1589) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0), 'icc_profile': b"\x00\x00\x02T\x00\x00\x00\x00\x04\x00\x00\x00mntrRGB XYZ \x07\xe0\x00\x0c\x00\x08\x00\t\x00&\x00\x1cacsp\x00\x00\x00\x00\x00\x00\x00\x00GOOG\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-GOOGu\xe1\xa6\xb1<47c\x10\xc8\xabf\x062\xa2\x8a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0bdesc\x00\x00\x01\x08\x00\x00\x00@cprt\x00\x00\x01H\x00\x00\x00Zwtpt\x00\x00\x01\xa4\x00\x00\x00\x14bkpt\x00\x00\x01\xb8\x00\x00\x00\x14rXYZ\x00\x00\x01\xcc\x00\x00\x00\x14gXYZ\x00\x00\x01\xe0\x00\x00\x00\x14bXYZ\x00\x00\x01\xf4\x00\x00\x00\x14rTRC\x00\x00\x02\x08\x00\x00\x00 chad\x00\x00\x02(\x00\x00\x00,bTRC\x00\x00\x02\x08\x00\x00\x00 gTRC\x00\x00\x02\x08\x00\x00\x00 mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x00$\x00\x00\x00\x1c\x00s\x00R\x00G\x00B\x00 \x00I\x00E\x00C\x006\x001\x009\x006\x006\x00-\x002\x00.\x001\x00\x00mluc\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x0cenUS\x00\x00\x00>\x00\x00\x00\x1c\x00C\x00o\x00p\x00y\x00r\x00i\x00g\x00h\x00t\x00 \x00(\x00c\x00)\x00 \x002\x000\x001\x006\x00 \x00G\x00o\x00o\x00g\x00l\x00e\x00 \x00I\x00n\x00c\x00.\x00\x00\x00\x00XYZ \x00\x00\x00\x00\x00\x00\xf3Q\x00\x01\x00\x00\x00\x01\x16\xccXYZ \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00XYZ \x00\x00\x00\x00\x00\x00o\xa0\x00\x008\xf5\x00\x00\x03\x90XYZ \x00\x00\x00\x00\x00\x00b\x97\x00\x00\xb7\x87\x00\x00\x18\xd9XYZ \x00\x00\x00\x00\x00\x00$\x9f\x00\x00\x0f\x84\x00\x00\xb6\xc3para\x00\x00\x00\x00\x00\x03\x00\x00\x00\x02ff\x00\x00\xf2\xa7\x00\x00\rY\x00\x00\x13\xd0\x00\x00\n[sf32\x00\x00\x00\x00\x00\x01\x0cB\x00\x00\x05\xde\xff\xff\xf3'\x00\x00\x07\x93\x00\x00\xfd\x90\xff\xff\xfb\xa3\xff\xff\xfd\xa4\x00\x00\x03\xdc\x00\x00\xc0n"}

# %%
output = 'figures/final_figures/fig2.tiff'
export_plos_tiff('figures/annotated_figures/fig2_collection_zone.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig2.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig3.tiff'
export_plos_tiff('figures/annotated_figures/fig3_anemone_anatomy.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig3.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig4.tiff'
export_plos_tiff('figures/annotated_figures/fig4_algal_reduction.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 6742 x 2978 px
# Resized to: 2250 x 993 px
# Saved PLOS-compliant TIFF to: figures/final_figures/fig4.tiff
# Mode: RGB
# Size: (2250, 993) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig5.tiff'
export_plos_tiff('figures/annotated_figures/fig5_algal_tidal_bars.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 6696 x 2957 px
# Resized to: 2250 x 993 px
# Saved PLOS-compliant TIFF to: figures/final_figures/fig5.tiff
# Mode: RGB
# Size: (2250, 993) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig6.tiff'
export_plos_tiff('figures/annotated_figures/fig6_chl_reduction.png', output_path=output)
inspect_image(output) 
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig6.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig7.tiff'
export_plos_tiff('figures/annotated_figures/fig7_chl_tidal_zones.png', output_path=output)
inspect_image(output) 
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig7.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig9.tiff'
export_plos_tiff('figures/annotated_figures/fig9_salinity.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig9.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig8.tiff'
export_plos_tiff('figures/annotated_figures/fig8_sst.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig8.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig10.tiff'
export_plos_tiff('figures/pre_annotated_figures/subplot_algae_salinity_temp_regression.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 3575 x 1469 px
# Resized to: 2250 x 924 px
# Saved PLOS-compliant TIFF to: figures/final_figures/fig10.tiff
# Mode: RGB
# Size: (2250, 924) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig11.tiff'
export_plos_tiff('figures/pre_annotated_figures/subplot_chl_salinity_temp_regression.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 3576 x 1469 px
# Resized to: 2250 x 924 px
# Saved PLOS-compliant TIFF to: figures/final_figures/fig11.tiff
# Mode: RGB
# Size: (2250, 924) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'figures/final_figures/fig12.tiff'
export_plos_tiff('figures/annotated_figures/fig12_tidal_box_plot.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 1280 x 720 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: figures/final_figures/fig12.tiff
# Mode: RGB
# Size: (1280, 720) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}
