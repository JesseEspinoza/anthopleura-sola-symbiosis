# %%
import sys
import os
# sys.path.append(os.path.expanduser('../../'))

from utils.visuals import export_plos_tiff, inspect_image, show_tiff

# %%
output = 'final_figures/fig1.tiff'

export_plos_tiff('drafted_figures/fig1_aramai_point_rocks.jpg', output_path= 'final_figures/fig1.tiff')
inspect_image('final_figures/fig1.tiff')
show_tiff('final_figures/fig1.tiff')
# Out:
# Original size: 2853 x 2015 px
# Resized to: 2250 x 1589 px
# Saved PLOS-compliant TIFF to: final_figures/fig1.tiff
# Mode: RGB
# Size: (2250, 1589) pixels
# ...

# %%
output = 'final_figures/fig4.tiff'
export_plos_tiff('drafted_figures/fig4_algal_reduction.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 6742 x 2978 px
# Resized to: 2250 x 993 px
# Saved PLOS-compliant TIFF to: final_figures/fig4.tiff
# Mode: RGB
# Size: (2250, 993) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig2.tiff'
export_plos_tiff('drafted_figures/fig2_collection_zone.jpg', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 800 x 600 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: final_figures/fig2.tiff
# Mode: RGB
# Size: (800, 600) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig3.tiff'
export_plos_tiff('drafted_figures/fig3_anemone_anatomy.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 770 x 530 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: final_figures/fig3.tiff
# Mode: RGB
# Size: (770, 530) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig11.tiff'
export_plos_tiff('plots/subplot_chl_salinity_temp_regression.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 3576 x 1469 px
# Resized to: 2250 x 924 px
# Saved PLOS-compliant TIFF to: final_figures/fig11.tiff
# Mode: RGB
# Size: (2250, 924) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig10.tiff'
export_plos_tiff('plots/subplot_algae_salinity_temp_regression.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 3575 x 1469 px
# Resized to: 2250 x 924 px
# Saved PLOS-compliant TIFF to: final_figures/fig10.tiff
# Mode: RGB
# Size: (2250, 924) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig5.tiff'
export_plos_tiff('plots/algal_tidal_bars.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 6696 x 2957 px
# Resized to: 2250 x 993 px
# Saved PLOS-compliant TIFF to: final_figures/fig5.tiff
# Mode: RGB
# Size: (2250, 993) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}

# %%
output = 'final_figures/fig6.tiff'
export_plos_tiff('plots/Untitled presentation.png', output_path=output)
inspect_image(output)
show_tiff(output)
# Out:
# Original size: 960 x 445 px
# Image is within allowed dimensions; no resize needed.
# Saved PLOS-compliant TIFF to: final_figures/fig6.tiff
# Mode: RGB
# Size: (960, 445) pixels
# Info: {'compression': 'tiff_lzw', 'dpi': (300.0, 300.0)}
